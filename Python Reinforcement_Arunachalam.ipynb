# %%
import pandas as pd
lap_data = pd.read_csv(r'C:\Users\HP\Desktop\python\class b\REINFOR\laptop\laptopData new.csv')

# %%
lap_data
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook   65.4
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
lap_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1273 non-null   float64
#  1   Company           1273 non-null   object
#  2   TypeName          1253 non-null   object
#  3   Inches            1220 non-null   object
#  4   ScreenResolution  1273 non-null   object
#  5   Cpu               1273 non-null   object
#  6   Ram               1259 non-null   object
#  7   Memory            1273 non-null   object
#  8   Gpu               1273 non-null   object
#  9   OpSys             1273 non-null   object
#  10  Weight            1259 non-null   object
#  11  Price             1273 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 122.3+ KB

# %%
lap_data=lap_data.copy()
lap_data
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook   65.4
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
lap_data.describe()
# Out:
#         Unnamed: 0          Price
# count  1273.000000    1273.000000
# mean    652.674784   59955.814073
# std     376.493027   37332.251005
# min       0.000000    9270.720000
# 25%     327.000000   31914.720000
# 50%     652.000000   52161.120000
# 75%     980.000000   79333.387200
# max    1302.000000  324954.720000

# %%
lap_data.shape
# Out:
# (1303, 12)

# %%
lap_data.head()
# Out:
#    Unnamed: 0 Company   TypeName Inches                    ScreenResolution  \
# 0         0.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
# 1         1.0   Apple  Ultrabook   13.3                            1440x900
# 2         2.0      HP   Notebook   15.6                   Full HD 1920x1080
# 3         3.0   Apple  Ultrabook   15.4  IPS Panel Retina Display 2880x1800
# 4         4.0   Apple  Ultrabook   13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
lap_data.tail(1072)
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 231        231.0      HP            Notebook   15.6
# 232        232.0  Lenovo              Gaming   15.6
# 233        233.0    Dell            Notebook     14
# 234        234.0    Acer  2 in 1 Convertible   13.3
# 235        235.0    Dell            Notebook   15.6
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook   65.4
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 231                                     1366x768
# 232                  IPS Panel Full HD 1920x1080
# 233                            Full HD 1920x1080
# 234    IPS Panel Full HD / Touchscreen 1920x1080
# 235                            Full HD 1920x1080
# ...

# %%
lap_data.size
# Out:
# 15636

# %%
# Data Cleaning

# %%
lap_data = lap_data.dropna(how='all')

# %%
duplicates = lap_data.drop_duplicates()
duplicates
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook   65.4
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
lap_data.shape
# Out:
# (1273, 12)

# %%
# removing "?" in 'Inches', 'Memory', 'Weight'
import numpy as np
lap_data.replace("?", np.nan, inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9964\92478107.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lap_data.replace("?", np.nan, inplace=True)

# %%
pd.isnull(lap_data).sum()
# Out:
# Unnamed: 0           0
# Company              0
# TypeName            20
# Inches              54
# ScreenResolution     0
# Cpu                  0
# Ram                 14
# Memory               1
# Gpu                  0
# OpSys                0
# Weight              15
# Price                0
# dtype: int64

# %%
lap_data['TypeName']=lap_data['TypeName'].fillna(lap_data['TypeName'].mode()[0])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9964\892955929.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lap_data['TypeName']=lap_data['TypeName'].fillna(lap_data['TypeName'].mode()[0])

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
lap_data.isnull().sum()
# Out:
# Unnamed: 0           0
# Company              0
# TypeName             0
# Inches              54
# ScreenResolution     0
# Cpu                  0
# Ram                 14
# Memory               1
# Gpu                  0
# OpSys                0
# Weight              15
# Price                0
# dtype: int64

# %%
lap_data['Inches'] = pd.to_numeric(lap_data['Inches'], errors='coerce')

# %%
lap_data['Inches']=lap_data['Inches'].fillna(lap_data['Inches'].median())

# %%
lap_data.isnull().sum()
# Out:
# Unnamed: 0           0
# Company              0
# TypeName             0
# Inches               0
# ScreenResolution     0
# Cpu                  0
# Ram                 14
# Memory               1
# Gpu                  0
# OpSys                0
# Weight              15
# Price                0
# dtype: int64

# %%
lap_data['Ram']=lap_data['Ram'].fillna(lap_data['Ram'].mode()[0])

# %%
lap_data.isnull().sum()
# Out:
# Unnamed: 0           0
# Company              0
# TypeName             0
# Inches               0
# ScreenResolution     0
# Cpu                  0
# Ram                  0
# Memory               1
# Gpu                  0
# OpSys                0
# Weight              15
# Price                0
# dtype: int64

# %%
lap_data['Weight_in_Kg'] = lap_data['Weight'].str.extract(r'([0-9.]+)')

# %%
lap_data['Weight_in_Kg']=lap_data['Weight_in_Kg'].astype(float)

# %%
lap_data['Weight_in_Kg']=lap_data['Weight_in_Kg'].fillna(lap_data['Weight_in_Kg'].median())

# %%
# droping the weight column in the table
lap_data.drop("Weight",axis=1,inplace=True)

# %%
lap_data
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0            0.0   Apple           Ultrabook    13.3
# 1            1.0   Apple           Ultrabook    13.3
# 2            2.0      HP            Notebook    15.6
# 3            3.0   Apple           Ultrabook    15.4
# 4            4.0   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298      1298.0  Lenovo  2 in 1 Convertible    14.0
# 1299      1299.0  Lenovo  2 in 1 Convertible    13.3
# 1300      1300.0  Lenovo            Notebook    65.4
# 1301      1301.0      HP            Notebook    15.6
# 1302      1302.0    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
lap_data.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              1
# Gpu                 0
# OpSys               0
# Price               0
# Weight_in_Kg        0
# dtype: int64

# %%
lap_data[lap_data['Memory'].isnull() == True]
# Out:
#      Unnamed: 0 Company  TypeName  Inches   ScreenResolution  \
# 770       770.0    Dell  Notebook    15.6  Full HD 1920x1080
#
#                             Cpu   Ram Memory                 Gpu       OpSys  \
# 770  Intel Core i7 7500U 2.7GHz  16GB    NaN  AMD Radeon R7 M445  Windows 10
#
#           Price  Weight_in_Kg
# 770  62938.0656           2.3

# %%
memfill = lap_data[(lap_data['Company'] == 'Dell') & (lap_data['TypeName'] == 'Notebook')].mode()

# %%
lap_data['Memory'] = lap_data['Memory'].fillna("1TB HDD")

# %%
lap_data.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Price               0
# Weight_in_Kg        0
# dtype: int64

# %%
# droping the unnamed 
lap_data.drop("Unnamed: 0",axis=1,inplace=True)

# %%
lap_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   float64
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Ram               1273 non-null   object
#  6   Memory            1273 non-null   object
#  7   Gpu               1273 non-null   object
#  8   OpSys             1273 non-null   object
#  9   Price             1273 non-null   float64
#  10  Weight_in_Kg      1273 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 119.3+ KB

# %%
lap_data['Ram in GB'] = lap_data['Ram'].str.extract(r'([0-9])')

# %%
lap_data['Ram in GB']=lap_data['Ram in GB'].astype(int)

# %%
lap_data.drop("Ram",axis=1,inplace=True)

# %%
lap_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   float64
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Memory            1273 non-null   object
#  6   Gpu               1273 non-null   object
#  7   OpSys             1273 non-null   object
#  8   Price             1273 non-null   float64
#  9   Weight_in_Kg      1273 non-null   float64
#  10  Ram in GB         1273 non-null   int32
# dtypes: float64(3), int32(1), object(7)
# memory usage: 114.4+ KB

# %%
lap_data['Price']=lap_data['Price'].astype(int)
lap_data
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    65.4
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
print("Price Summary:")
print(lap_data['Price'].describe())
# Out:
# Price Summary:
# count      1273.000000
# mean      59955.311076
# std       37332.247865
# min        9270.000000
# 25%       31914.000000
# 50%       52161.000000
# 75%       79333.000000
# max      324954.000000
# Name: Price, dtype: float64

# %%
lap_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1273 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1273 non-null   object
#  1   TypeName          1273 non-null   object
#  2   Inches            1273 non-null   float64
#  3   ScreenResolution  1273 non-null   object
#  4   Cpu               1273 non-null   object
#  5   Memory            1273 non-null   object
#  6   Gpu               1273 non-null   object
#  7   OpSys             1273 non-null   object
#  8   Price             1273 non-null   int32
#  9   Weight_in_Kg      1273 non-null   float64
#  10  Ram in GB         1273 non-null   int32
# dtypes: float64(2), int32(2), object(7)
# memory usage: 109.4+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
# uni-variate analyis
ram_counts = lap_data['Ram in GB'].value_counts().sort_index()

plt.figure(figsize=(10, 5))
plt.bar(ram_counts.index, ram_counts.values, color='blue')
plt.title('Bar Plot of RAM Sizes')
plt.xlabel('RAM (GB)')
plt.ylabel('Number of Laptops')
plt.xticks(ram_counts.index)
plt.show()

# %%
# to view the price
plt.figure(figsize=(10, 3))
sns.boxplot(x=lap_data['Price'], color='skyblue')
plt.title('Box Plot of Laptop Prices')
plt.xlabel('Price')
plt.show()

# %%
# bivariate
ram_price = lap_data.groupby('Ram in GB')['Price'].mean().reset_index()

plt.figure(figsize=(8, 5))
sns.lineplot(x='Ram in GB', y='Price', data=ram_price, marker='o', color='black')
plt.title('Average Price by RAM Size')
plt.xlabel('RAM (GB)')
plt.ylabel('Average Price')
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.scatterplot(x='Cpu', y='Price', data=lap_data.head(150))
plt.xticks(rotation=100)
plt.title('Price Distribution by CPU Type')
plt.xlabel('CPU')
plt.ylabel('Price')
plt.show()

# %%
#multivariate
numeric_cols = ['Price', 'Ram in GB', 'Weight_in_Kg', 'Inches']  # Add more if available
sns.pairplot(lap_data[numeric_cols], 
             kind='scatter', 
             diag_kind='kde',   # Kernel Density Estimation on diagonals
             plot_kws={'alpha': 0.6, 's': 50, 'edgecolor': 'k'})
plt.suptitle('Multivariate Pair Plot of Laptop Features', y=1.02)
plt.tight_layout()
plt.show()

# %%
lap_data
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    65.4
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
# # Sorting out the Outliers for Weight_in_Kg & Inches 
plt.boxplot(lap_data[[ 'Weight_in_Kg','Inches']])
plt.xticks([1,2,],['Weight_in_Kg','Inches'])
plt.ylabel('Values')
plt.title('Box Plot')
plt.show()

# %%
# changing Weight_in_Kg outliers
Q1 = lap_data['Weight_in_Kg'].quantile(0.25)
Q3 = lap_data['Weight_in_Kg'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Lower Bound: {lower_bound}")
print(f"Upper Bound: {upper_bound}")

# calculate the median
median_value = lap_data['Weight_in_Kg'].median()
print(f"Median Value: {median_value}")

# replace outliers with mode
lap_data['Weight_in_Kg'] = np.where((lap_data['Weight_in_Kg'] < lower_bound) | (lap_data['Weight_in_Kg'] > upper_bound), median_value, lap_data['Weight_in_Kg'])

print("Data after Replacing Outliers With Median:\n",lap_data)
# Out:
# Lower Bound: 0.2549999999999999
# Upper Bound: 3.575
# Median Value: 2.04
# Data after Replacing Outliers With Median:
#       Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    65.4
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
# changing Weight_in_Kg outliers
Q1 = lap_data['Inches'].quantile(0.25)
Q3 = lap_data['Inches'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Lower Bound: {lower_bound}")
print(f"Upper Bound: {upper_bound}")

# calculate the median
median_value = lap_data['Inches'].median()
print(f"Median Value: {median_value}")

# replace outliers with mode
lap_data['Inches'] = np.where((lap_data['Inches'] < lower_bound) | (lap_data['Inches'] > upper_bound), median_value, lap_data['Inches'])

print("Data after Replacing Outliers With Median:\n",lap_data)
# Out:
# Lower Bound: 11.600000000000001
# Upper Bound: 18.0
# Median Value: 15.6
# Data after Replacing Outliers With Median:
#       Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    15.6
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
# Result after sorting outliers
plt.boxplot(lap_data[[ 'Weight_in_Kg','Inches']])
plt.xticks([1,2,],['Weight_in_Kg','Inches'])
plt.ylabel('Values')
plt.title('Box Plot')
plt.show()

# %%
lap_data
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    15.6
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
# Visualization
#scatter plot
plt.figure(figsize=(20, 6))
sns.scatterplot(x='Company', y='Price', data=lap_data)
plt.xticks(rotation=45)
plt.title('Price Distribution by CPU Type')
plt.xlabel('Company')
plt.ylabel('Price')
plt.show()

# %%
#univariate
sns.histplot(lap_data["Weight_in_Kg"],color="purple",kde=True)
plt.title("Distribution_Of_Weight_in_Kg")
plt.xlabel("Weight_in_Kg")
plt.ylabel("Sold Unit")
plt.show()

# %%
plt.figure(figsize=(16, 6)) 
sns.violinplot(x="TypeName",y="Price",data=lap_data,palette="pastel")
plt.show()

# %%
# Using subplot for showing the total number of sales by TYPENAME
laptype_data = lap_data["TypeName"].value_counts().reset_index()

fig, ax = plt.subplots(figsize=(19,6))
bars = ax.bar(laptype_data["TypeName"], laptype_data["count"], color="skyblue")
ax.bar_label(bars)

plt.title("Total sales by Version")
plt.show()

# %%
company_data = lap_data["Company"].value_counts().reset_index()

fig, ax = plt.subplots(figsize=(19,6))
bars = ax.bar(company_data["Company"], company_data["count"], color="blue")
ax.bar_label(bars)

plt.title("Sale by Brand")
plt.show()

# %%
# FEATURE Engineering:
#created the funcction for setting the new column for segment laptops
# Function to categorize laptop price into preference levels
def category_preference(price):
    if price <= 45000:
        return "Tier 3 / Low End Model  " 
    elif 45000 < price <= 75000:
        return "Tier 2 / Mid-End Model"
    else:
        return "Tier 1 / Premium-End"

lap_data["Preference"] = lap_data["Price"].apply(category_preference)

# %%
#created function for categories the apple & window laptops
def laptop_brand(OpSys):
    if "macOS" in OpSys or "Mac OS X" in OpSys:
        return "Mac"
    elif "Windows" in OpSys:
        return "Windows"
    elif "Linux" in OpSys:
        return "Linux"
    elif "Chrome" in OpSys:
        return "Chrome OS"
    elif "Android" in OpSys:
        return "Android"
    else:
        return "Other"

lap_data["OS_Type"] = lap_data["OpSys"].apply(laptop_brand)

# %%
lap_data
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    15.6
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
preference_data = lap_data["Preference"].value_counts().reset_index()

plt.pie(data=preference_data,x="count",labels="Preference",autopct = "%1.1f%%",colors = ['skyblue', 'lightgreen', 'orange'])
plt.legend(loc = "right",bbox_to_anchor = (2,0.5))
plt.title("Laptop Preference")
plt.show()

# %%
# T test independent testing
from scipy.stats import ttest_ind
dell_prices = lap_data[lap_data['Company'] == 'Dell']['Price']
hp_prices = lap_data[lap_data['Company'] == 'HP']['Price']

stat, p_value = ttest_ind(dell_prices, hp_prices)
print("T-statistic:", stat)
print("P-value:", p_value)
if p_value < 0.05:
    print("Reject the null hypothesis")
else:
    print("Fail to reject the null hypothesis")
# Out:
# T-statistic: 2.0366358749657705
# P-value: 0.04216408728364471
# Reject the null hypothesis

# %%
# ANNOVA One way Annova
from scipy.stats import f_oneway

ram_sizes = lap_data['Ram in GB'].unique()
grouped_prices = [lap_data[lap_data['Ram in GB'] == r]['Price'] for r in ram_sizes]

# Perform the ANOVA test
stat, p = f_oneway(*grouped_prices)
print("F-statistic:", stat)
print("P-value:", p)

if p < 0.05:
    print("Reject the null hypothesis: At least one RAM group has a different mean price.")
else:
    print("Fail to reject the null hypothesis: No significant mean price difference between RAM groups.")
# Out:
# F-statistic: 287.67420905106627
# P-value: 9.181674559738192e-206
# Reject the null hypothesis: At least one RAM group has a different mean price.
